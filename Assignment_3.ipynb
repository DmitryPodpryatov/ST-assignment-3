# %%
from google.colab import drive

drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %% [markdown]
# # Read Dataset
#
# Retrieve top 30 cities by population

# %%
import pandas as pd

# https://simplemaps.com/data/ru-cities
dataset = pd.read_csv('drive/MyDrive/Colab Notebooks/STfDSR/Assignment 3/ru.csv')

# %%
top_30 = dataset.head(30)

top_30
# Out:
#                 city      lat       lng country iso2               admin_name  \
# 0             Moscow  55.7558   37.6178  Russia   RU                   Moskva
# 1   Saint Petersburg  59.9500   30.3167  Russia   RU          Sankt-Peterburg
# 2        Novosibirsk  55.0333   82.9167  Russia   RU   Novosibirskaya Oblast’
# 3      Yekaterinburg  56.8356   60.6128  Russia   RU    Sverdlovskaya Oblast’
# 4   Nizhniy Novgorod  56.3269   44.0075  Russia   RU  Nizhegorodskaya Oblast’
# 5              Kazan  55.7908   49.1144  Russia   RU                Tatarstan
# 6        Chelyabinsk  55.1500   61.4000  Russia   RU   Chelyabinskaya Oblast’
# 7               Omsk  54.9667   73.3833  Russia   RU          Omskaya Oblast’
# 8             Samara  53.1833   50.1167  Russia   RU       Samarskaya Oblast’
# 9             Rostov  47.2333   39.7167  Russia   RU      Rostovskaya Oblast’
# 10               Ufa  54.7333   55.9667  Russia   RU            Bashkortostan
# 11       Krasnoyarsk  56.0167   92.8667  Russia   RU       Krasnoyarskiy Kray
# 12              Perm  58.0139   56.2489  Russia   RU            Permskiy Kray
# 13          Voronezh  51.6717   39.2106  Russia   RU    Voronezhskaya Oblast’
# 14         Volgograd  48.7086   44.5147  Russia   RU   Volgogradskaya Oblast’
# 15         Krasnodar  45.0333   38.9833  Russia   RU       Krasnodarskiy Kray
# 16           Saratov  51.5333   46.0000  Russia   RU     Saratovskaya Oblast’
# 17            Tyumen  57.1500   65.5333  Russia   RU      Tyumenskaya Oblast’
# 18          Tolyatti  53.5167   49.4167  Russia   RU       Samarskaya Oblast’
# 19           Izhevsk  56.8500   53.2167  Russia   RU                Udmurtiya
# 20           Barnaul  53.3567   83.7872  Russia   RU           Altayskiy Kray
# 21         Ulyanovsk  54.3167   48.3667  Russia   RU    Ul’yanovskaya Oblast’
# 22           Irkutsk  52.2833  104.3000  Russia   RU       Irkutskaya Oblast’
# 23        Khabarovsk  48.4833  135.0667  Russia   RU        Khabarovskiy Kray
# 24         Yaroslavl  57.6167   39.8500  Russia   RU    Yaroslavskaya Oblast’
# 25       Vladivostok  43.1167  131.9000  Russia   RU          Primorskiy Kray
# 26       Makhachkala  42.9833   47.4833  Russia   RU                 Dagestan
# 27             Tomsk  56.4886   84.9522  Russia   RU         Tomskaya Oblast’
# 28          Orenburg  51.7667   55.1000  Russia   RU    Orenburgskaya Oblast’
# 29          Kemerovo  55.3333   86.0667  Russia   RU     Kemerovskaya Oblast’
#
#     capital  population  population_proper
# 0   primary  17125000.0         13200000.0
# 1     admin   5351935.0          5351935.0
# 2     admin   1602915.0          1602915.0
# 3     admin   1468833.0          1468833.0
# 4     admin   1264075.0          1264075.0
# 5     admin   1243500.0          1243500.0
# 6     admin   1202371.0          1202371.0
# 7     admin   1178391.0          1178391.0
# 8     admin   1169719.0          1169719.0
# 9     admin   1125299.0          1125299.0
# 10    admin   1115560.0          1115560.0
# 11    admin   1083865.0          1083865.0
# 12    admin   1048005.0          1048005.0
# 13    admin   1047549.0          1047549.0
# 14    admin   1015586.0          1015586.0
# 15    admin    881476.0           881476.0
# 16    admin    845300.0           845300.0
# 17    admin    744554.0           744554.0
# 18      NaN    707408.0           707408.0
# 19    admin    646277.0           646277.0
# 20    admin    633301.0           633301.0
# 21    admin    624518.0           624518.0
# 22    admin    623736.0           623736.0
# 23    admin    616242.0           616242.0
# 24    admin    608079.0           608079.0
# 25    admin    606589.0           606589.0
# 26    admin    592976.0           592976.0
# 27    admin    572740.0           572740.0
# 28    admin    564443.0           564443.0
# 29    admin    556920.0           556920.0

# %%
top_30 = top_30[['city', 'lat', 'lng']]

top_30.head(1)
# Out:
#      city      lat      lng
# 0  Moscow  55.7558  37.6178

# %% [markdown]
# # Setup Plotting
#
# Use `plotly` for drawing objects on a globe.
# Especially helpful for plotting cities and preserving the distances

# %%
import plotly.graph_objects as go

moscow = top_30.head(1)


def map_cities():
    fig = go.Figure()

    fig.add_trace(
        # https://plotly.github.io/plotly.py-docs/generated/plotly.graph_objects.Scattergeo.html
        go.Scattergeo(
            locationmode='country names',
            lon=top_30['lng'],
            lat=top_30['lat'],
            text=top_30['city'],
            textfont=dict(
                color='rgb(0, 0, 0)'
            ),
            textposition='bottom right',
            hoverinfo='text',
            mode='markers',
            marker=dict(
                size=4,
                color='rgb(0, 0, 255)',
            )
        )
    )

    return fig


def setup_map(fig, center):
    fig.update_layout(
        title_text='Top 30 largest cities in Russia',
        showlegend=False,
        # https://plotly.com/python/reference/layout/geo/
        # Move satellite over the center of Russia
        geo=dict(
            scope='world',
            center=dict(
                lat=center['lat'][0],
                lon=center['lng'][0] + 22.0
            ),
            projection_rotation=dict(
                lat=center['lat'][0],
                lon=center['lng'][0],
                roll=-37
            ),
            projection_type='cylindrical stereographic',
            projection_scale=4.5,
            showland=True,
            showcountries=True,
            landcolor='rgb(243, 243, 243)',
            countrycolor='rgb(204, 204, 204)',
        ),
    )

    return fig


fig = map_cities()
fig = setup_map(fig, moscow)
fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script src="https://cdn.plot.ly/plotly-2.8.3.min.js"></script>                <div id="bbd1557f-c9bc-4cd8-a547-6e2125b5bdcc" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("bbd1557f-c9bc-4cd8-a547-6e2125b5bdcc")) {                    Plotly.newPlot(                        "bbd1557f-c9bc-4cd8-a547-6e2125b5bdcc",                        [{"hoverinfo":"text","lat":[55.7558,59.95,55.0333,56.8356,56.3269,55.7908,55.15,54.9667,53.1833,47.2333,54.7333,56.0167,58.0139,51.6717,48.7086,45.0333,51.5333,57.15,53.5167,56.85,53.3567,54.3167,52.2833,48.4833,57.6167,43.1167,42.9833,56.4886,51.7667,55.3333],"locationmode":"country names","lon":[37.6178,30.3167,82.9167,60.6128,44.0075,49.1144,61.4,73.3833,50.1167,39.7167,55.9667,92.8667,56.2489,39.2106,44.5147,38.9833,46.0,65.5333,49.4167,53.2167,83.7872,48.3667,104.3,135.0667,39.85,131.9,47.4833,84.9522,55.1,86.0667],"marker":{"color":"rgb(0, 0, 255)","size":4},"mode":"markers","text":["Moscow","Saint Petersburg","Novosibirsk","Yekaterinburg","Nizhniy Novgorod","Kazan","Chelyabinsk","Omsk","Samara","Rostov","Ufa","Krasnoyarsk","Perm","Voronezh","Volgograd","Krasnodar","Saratov","Tyumen","Tolyatti","Izhevsk","Barnaul","Ulyanovsk","Irkutsk","Khabarovsk","Yaroslavl","Vladivostok","Makhachkala","Tomsk","Orenburg","Kemerovo"],"textfont":{"color":"rgb(0, 0, 0)"},"textposition":"bottom right","type":"scattergeo"}],                        {"template":{"data":{"bar":[{"error_x":{"color":"#2a3f5f"},"error_y":{"color":"#2a3f5f"},"marker":{"line":{"color":"#E5ECF6","width":0.5},"pattern":{"fillmode":"overlay","size":10,"solidity":0.2}},"type":"bar"}],"barpolar":[{"marker":{"line":{"color":"#E5ECF6","width":0.5},"pattern":{"fillmode":"overlay","size":10,"solidity":0.2}},"type":"barpolar"}],"carpet":[{"aaxis":{"endlinecolor":"#2a3f5f","gridcolor":"white","linecolor":"white","minorgridcolor":"white","startlinecolor":"#2a3f5f"},"baxis":{"endlinecolor":"#2a3f5f","gridcolor":"white","linecolor":"white","minorgridcolor":"white","startlinecolor":"#2a3f5f"},"type":"carpet"}],"choropleth":[{"colorbar":{"outlinewidth":0,"ticks":""},"type":"choropleth"}],"contour":[{"colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]],"type":"contour"}],"contourcarpet":[{"colorbar":{"outlinewidth":0,"ticks":""},"type":"contourcarpet"}],"heatmap":[{"colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]],"type":"heatmap"}],"heatmapgl":[{"colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]],"type":"heatmapgl"}],"histogram":[{"marker":{"pattern":{"fillmode":"overlay","size":10,"solidity":0.2}},"type":"histogram"}],"histogram2d":[{"colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]],"type":"histogram2d"}],"histogram2dcontour":[ ...

# %%
from dataclasses import dataclass


@dataclass
class City:
    name: str
    lat: float
    lng: float

    def __init__(self, city):
        self.name = city['city']
        self.lat = city['lat']
        self.lng = city['lng']


cities = []

for city in top_30.T.to_dict().values():
    cities.append(City(city))

cities[0]
# Out:
# City(name='Moscow', lat=55.7558, lng=37.6178)

# %%
from geopy.distance import geodesic
import numpy as np


def get_distance(point1, point2):
    """
    Convert from spherical to cartesian coordinate system
    (lat, long), (lat, long)
    """
    return geodesic(point1, point2).km


def get_cross_distances(cities):
    n = len(cities)

    matrix = np.empty((n, n), dtype=np.int32).tolist()

    for i in range(n):
        for j in range(n):
            if cities[i].name == cities[j].name:
                matrix[i][j] = 0
            else:
                point1 = cities[i].lat, cities[i].lng
                point2 = cities[j].lat, cities[j].lng

                matrix[i][j] = get_distance(point1, point2)

    return matrix

# %% [markdown]
# # Simulated Annealing
#
# Find the optimal traveling salesman path with a combinatorial optimization

# %%
import math
from numpy.random import uniform
from random import sample, shuffle


class SA:
    def __init__(self, cities, annealing_rate=0.99):
        self.n = len(cities)

        self.cities = cities
        self.indices = [i for i, _ in enumerate(cities)]
        self.distances = get_cross_distances(cities)

        self.t = 0

        # Store T_0 for exponential decay
        self.T_0 = 100_000
        self.T = self.T_0

        # Lambda
        self.annealing_rate = annealing_rate

        # Current path
        self.x_t = self.sample_path()

        # Placing the threshold so low was causing DivisionByZero exceptions
        # See `def acceptance_ratio`
        while self.T > 10:
            self.loop()
        else:
            print('Simulated Annealing Stopped')
            print(f'Total distance: {self.path_distance(self.x_t)} km')
            print(f'Took {self.t} iterations')

    def sample_path(self, path=None):
        if path is None:
            sample_indices = self.indices.copy()

            # shuffles in place
            shuffle(sample_indices)

            # Close the loop
            return sample_indices + [sample_indices[0]]
        else:
            idx1, idx2 = sample(self.indices, k=2)

            # Undo the loop to get unique indices
            sample_indices = path[:-1].copy()
            sample_indices[idx1], sample_indices[idx2] = sample_indices[idx2], sample_indices[idx1]

            # Close the loop again
            return sample_indices + [sample_indices[0]]

    def path_distance(self, path):
        total = 0

        for i in range(1, len(path)):
            total += self.distances[path[i - 1]][path[i]]

        return total

    def energy(self, path):
        return math.exp(-1 * self.path_distance(path) / self.T)

    def acceptance_ratio(self, x_next):
        """
        Cannot really explain why return 0 in case of small denumerator.
        But it works! And 1 does not.
        """
        try:
            return self.energy(x_next) / self.energy(self.x_t)
        except ZeroDivisionError:
            return 0

    def generate_uniform(self):
        return uniform(0, 1)

    def loop(self):
        x_next = self.sample_path(self.x_t)

        alpha = self.acceptance_ratio(x_next)
        u = self.generate_uniform()

        if alpha >= u:
            self.x_t = x_next

        self.t += 1

        if self.generate_uniform() < 0.2:
            self.T = self.T_0 * math.exp(-1 * self.annealing_rate * self.t)

# %%
def plot_optimization_results(sa):
    shortest_path = sa.x_t
    shortest_path = [sa.cities[idx] for idx in shortest_path]

    city_pairs = [
        (shortest_path[i - 1], shortest_path[i])
        for i in range(1, len(shortest_path))
    ]

    fig = map_cities()

    # Draw lines
    for city1, city2 in city_pairs:
        fig.add_trace(
            go.Scattergeo(
                locationmode='country names',
                lat=[city1.lat, city2.lat],
                lon=[city1.lng, city2.lng],
                text='',
                hoverinfo='none',
                mode='lines+text',
                line=dict(width=1, color='red'),
                opacity=0.7,
            )
        )

    fig = setup_map(fig, moscow)
    fig.show()

# %% [markdown]
# ## Slow Cooling

# %%
plot_optimization_results(SA(cities, annealing_rate=0.0001))
# Out:
# Simulated Annealing Stopped
# Total distance: 18371.839082095452 km
# Took 92107 iterations
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script src="https://cdn.plot.ly/plotly-2.8.3.min.js"></script>                <div id="22655a97-9ae4-4364-9113-cbd5a225cf74" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("22655a97-9ae4-4364-9113-cbd5a225cf74")) {                    Plotly.newPlot(                        "22655a97-9ae4-4364-9113-cbd5a225cf74",                        [{"hoverinfo":"text","lat":[55.7558,59.95,55.0333,56.8356,56.3269,55.7908,55.15,54.9667,53.1833,47.2333,54.7333,56.0167,58.0139,51.6717,48.7086,45.0333,51.5333,57.15,53.5167,56.85,53.3567,54.3167,52.2833,48.4833,57.6167,43.1167,42.9833,56.4886,51.7667,55.3333],"locationmode":"country names","lon":[37.6178,30.3167,82.9167,60.6128,44.0075,49.1144,61.4,73.3833,50.1167,39.7167,55.9667,92.8667,56.2489,39.2106,44.5147,38.9833,46.0,65.5333,49.4167,53.2167,83.7872,48.3667,104.3,135.0667,39.85,131.9,47.4833,84.9522,55.1,86.0667],"marker":{"color":"rgb(0, 0, 255)","size":4},"mode":"markers","text":["Moscow","Saint Petersburg","Novosibirsk","Yekaterinburg","Nizhniy Novgorod","Kazan","Chelyabinsk","Omsk","Samara","Rostov","Ufa","Krasnoyarsk","Perm","Voronezh","Volgograd","Krasnodar","Saratov","Tyumen","Tolyatti","Izhevsk","Barnaul","Ulyanovsk","Irkutsk","Khabarovsk","Yaroslavl","Vladivostok","Makhachkala","Tomsk","Orenburg","Kemerovo"],"textfont":{"color":"rgb(0, 0, 0)"},"textposition":"bottom right","type":"scattergeo"},{"hoverinfo":"none","lat":[58.0139,56.8356],"line":{"color":"red","width":1},"locationmode":"country names","lon":[56.2489,60.6128],"mode":"lines+text","opacity":0.7,"text":"","type":"scattergeo"},{"hoverinfo":"none","lat":[56.8356,57.15],"line":{"color":"red","width":1},"locationmode":"country names","lon":[60.6128,65.5333],"mode":"lines+text","opacity":0.7,"text":"","type":"scattergeo"},{"hoverinfo":"none","lat":[57.15,55.0333],"line":{"color":"red","width":1},"locationmode":"country names","lon":[65.5333,82.9167],"mode":"lines+text","opacity":0.7,"text":"","type":"scattergeo"},{"hoverinfo":"none","lat":[55.0333,55.3333],"line":{"color":"red","width":1},"locationmode":"country names","lon":[82.9167,86.0667],"mode":"lines+text","opacity":0.7,"text":"","type":"scattergeo"},{"hoverinfo":"none","lat":[55.3333,56.4886],"line":{"color":"red","width":1},"locationmode":"country names","lon":[86.0667,84.9522],"mode":"lines+text","opacity":0.7,"text":"","type":"scattergeo"},{"hoverinfo":"none","lat":[56.4886,56.0167],"line":{"color":"red","width":1},"locationmode":"country names","lon":[84.9522,92.8667],"mode":"lines+text","opacity":0.7,"text":"","type":"scattergeo"},{"hoverinfo":"none","lat":[56.0167,48.4833],"line":{"color":"red","width":1},"locationmode":"country names","lon":[92.8667,135.0667],"mode":"lines+text","opacity":0.7,"text":"","type":"scattergeo"},{"hoverinfo":"none","lat":[48.4833,43.1167],"line":{"color":"red","width":1},"locationmode":"country names","lon":[135.0667,131.9],"mode":"lines+text","opacity":0.7,"text":"","type":"scattergeo"},{"hoverinfo":"none","lat":[43.1167,52.2833],"line":{"color":"red","width":1},"locationmode":"country names","lon":[131.9,104.3],"mode":"lines+text","opacity":0.7,"text":"","type":"scattergeo"},{"hoverinfo":"none","lat":[52.2833,53.3567],"line":{"color":"red","width":1},"locationmode":"country names","lon":[104.3,83.7872],"mode":"lines+text","opacity":0.7,"text":"","type":"scattergeo"},{"hoverinfo":"none","lat":[53.3567,54.9667],"line":{"color":"red","width":1},"locationmode":"country names","lon":[83.7872,73.3833],"mode":"lines+text","opacity":0.7,"text":"","type":"scattergeo"},{"hoverinfo":"none","lat":[54.9667,55.15],"line":{"color":"red","width":1},"locationmode":"country names","lon":[73.3833,61.4],"mode":"lines+text","opacity":0.7,"text":"","type":"scattergeo"},{"hoverinfo":"none","lat":[55.15,54.7333],"line":{"color":"red","width":1},"loca ...

# %% [markdown]
# ## Fast Cooling

# %%
plot_optimization_results(SA(cities, annealing_rate=0.9999))
# Out:
# Simulated Annealing Stopped
# Total distance: 55637.975568348855 km
# Took 10 iterations
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script src="https://cdn.plot.ly/plotly-2.8.3.min.js"></script>                <div id="870f8493-b399-4c31-936b-d952e9e750b7" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("870f8493-b399-4c31-936b-d952e9e750b7")) {                    Plotly.newPlot(                        "870f8493-b399-4c31-936b-d952e9e750b7",                        [{"hoverinfo":"text","lat":[55.7558,59.95,55.0333,56.8356,56.3269,55.7908,55.15,54.9667,53.1833,47.2333,54.7333,56.0167,58.0139,51.6717,48.7086,45.0333,51.5333,57.15,53.5167,56.85,53.3567,54.3167,52.2833,48.4833,57.6167,43.1167,42.9833,56.4886,51.7667,55.3333],"locationmode":"country names","lon":[37.6178,30.3167,82.9167,60.6128,44.0075,49.1144,61.4,73.3833,50.1167,39.7167,55.9667,92.8667,56.2489,39.2106,44.5147,38.9833,46.0,65.5333,49.4167,53.2167,83.7872,48.3667,104.3,135.0667,39.85,131.9,47.4833,84.9522,55.1,86.0667],"marker":{"color":"rgb(0, 0, 255)","size":4},"mode":"markers","text":["Moscow","Saint Petersburg","Novosibirsk","Yekaterinburg","Nizhniy Novgorod","Kazan","Chelyabinsk","Omsk","Samara","Rostov","Ufa","Krasnoyarsk","Perm","Voronezh","Volgograd","Krasnodar","Saratov","Tyumen","Tolyatti","Izhevsk","Barnaul","Ulyanovsk","Irkutsk","Khabarovsk","Yaroslavl","Vladivostok","Makhachkala","Tomsk","Orenburg","Kemerovo"],"textfont":{"color":"rgb(0, 0, 0)"},"textposition":"bottom right","type":"scattergeo"},{"hoverinfo":"none","lat":[47.2333,48.7086],"line":{"color":"red","width":1},"locationmode":"country names","lon":[39.7167,44.5147],"mode":"lines+text","opacity":0.7,"text":"","type":"scattergeo"},{"hoverinfo":"none","lat":[48.7086,51.5333],"line":{"color":"red","width":1},"locationmode":"country names","lon":[44.5147,46.0],"mode":"lines+text","opacity":0.7,"text":"","type":"scattergeo"},{"hoverinfo":"none","lat":[51.5333,53.1833],"line":{"color":"red","width":1},"locationmode":"country names","lon":[46.0,50.1167],"mode":"lines+text","opacity":0.7,"text":"","type":"scattergeo"},{"hoverinfo":"none","lat":[53.1833,57.15],"line":{"color":"red","width":1},"locationmode":"country names","lon":[50.1167,65.5333],"mode":"lines+text","opacity":0.7,"text":"","type":"scattergeo"},{"hoverinfo":"none","lat":[57.15,51.7667],"line":{"color":"red","width":1},"locationmode":"country names","lon":[65.5333,55.1],"mode":"lines+text","opacity":0.7,"text":"","type":"scattergeo"},{"hoverinfo":"none","lat":[51.7667,52.2833],"line":{"color":"red","width":1},"locationmode":"country names","lon":[55.1,104.3],"mode":"lines+text","opacity":0.7,"text":"","type":"scattergeo"},{"hoverinfo":"none","lat":[52.2833,51.6717],"line":{"color":"red","width":1},"locationmode":"country names","lon":[104.3,39.2106],"mode":"lines+text","opacity":0.7,"text":"","type":"scattergeo"},{"hoverinfo":"none","lat":[51.6717,58.0139],"line":{"color":"red","width":1},"locationmode":"country names","lon":[39.2106,56.2489],"mode":"lines+text","opacity":0.7,"text":"","type":"scattergeo"},{"hoverinfo":"none","lat":[58.0139,55.3333],"line":{"color":"red","width":1},"locationmode":"country names","lon":[56.2489,86.0667],"mode":"lines+text","opacity":0.7,"text":"","type":"scattergeo"},{"hoverinfo":"none","lat":[55.3333,42.9833],"line":{"color":"red","width":1},"locationmode":"country names","lon":[86.0667,47.4833],"mode":"lines+text","opacity":0.7,"text":"","type":"scattergeo"},{"hoverinfo":"none","lat":[42.9833,56.85],"line":{"color":"red","width":1},"locationmode":"country names","lon":[47.4833,53.2167],"mode":"lines+text","opacity":0.7,"text":"","type":"scattergeo"},{"hoverinfo":"none","lat":[56.85,53.3567],"line":{"color":"red","width":1},"locationmode":"country names","lon":[53.2167,83.7872],"mode":"lines+text","opacity":0.7,"text":"","type":"scattergeo"},{"hoverinfo":"none","lat":[53.3567,55.0333],"line":{"color":"red","width":1},"locationmod ...

# %% [markdown]
# ## Average Cooling

# %%
plot_optimization_results(SA(cities, annealing_rate=0.5))
# Out:
# Simulated Annealing Stopped
# Total distance: 64220.74606180252 km
# Took 20 iterations
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script src="https://cdn.plot.ly/plotly-2.8.3.min.js"></script>                <div id="65ed221b-838d-4942-a374-0b5247d9be24" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("65ed221b-838d-4942-a374-0b5247d9be24")) {                    Plotly.newPlot(                        "65ed221b-838d-4942-a374-0b5247d9be24",                        [{"hoverinfo":"text","lat":[55.7558,59.95,55.0333,56.8356,56.3269,55.7908,55.15,54.9667,53.1833,47.2333,54.7333,56.0167,58.0139,51.6717,48.7086,45.0333,51.5333,57.15,53.5167,56.85,53.3567,54.3167,52.2833,48.4833,57.6167,43.1167,42.9833,56.4886,51.7667,55.3333],"locationmode":"country names","lon":[37.6178,30.3167,82.9167,60.6128,44.0075,49.1144,61.4,73.3833,50.1167,39.7167,55.9667,92.8667,56.2489,39.2106,44.5147,38.9833,46.0,65.5333,49.4167,53.2167,83.7872,48.3667,104.3,135.0667,39.85,131.9,47.4833,84.9522,55.1,86.0667],"marker":{"color":"rgb(0, 0, 255)","size":4},"mode":"markers","text":["Moscow","Saint Petersburg","Novosibirsk","Yekaterinburg","Nizhniy Novgorod","Kazan","Chelyabinsk","Omsk","Samara","Rostov","Ufa","Krasnoyarsk","Perm","Voronezh","Volgograd","Krasnodar","Saratov","Tyumen","Tolyatti","Izhevsk","Barnaul","Ulyanovsk","Irkutsk","Khabarovsk","Yaroslavl","Vladivostok","Makhachkala","Tomsk","Orenburg","Kemerovo"],"textfont":{"color":"rgb(0, 0, 0)"},"textposition":"bottom right","type":"scattergeo"},{"hoverinfo":"none","lat":[51.5333,51.7667],"line":{"color":"red","width":1},"locationmode":"country names","lon":[46.0,55.1],"mode":"lines+text","opacity":0.7,"text":"","type":"scattergeo"},{"hoverinfo":"none","lat":[51.7667,57.6167],"line":{"color":"red","width":1},"locationmode":"country names","lon":[55.1,39.85],"mode":"lines+text","opacity":0.7,"text":"","type":"scattergeo"},{"hoverinfo":"none","lat":[57.6167,56.0167],"line":{"color":"red","width":1},"locationmode":"country names","lon":[39.85,92.8667],"mode":"lines+text","opacity":0.7,"text":"","type":"scattergeo"},{"hoverinfo":"none","lat":[56.0167,45.0333],"line":{"color":"red","width":1},"locationmode":"country names","lon":[92.8667,38.9833],"mode":"lines+text","opacity":0.7,"text":"","type":"scattergeo"},{"hoverinfo":"none","lat":[45.0333,56.3269],"line":{"color":"red","width":1},"locationmode":"country names","lon":[38.9833,44.0075],"mode":"lines+text","opacity":0.7,"text":"","type":"scattergeo"},{"hoverinfo":"none","lat":[56.3269,42.9833],"line":{"color":"red","width":1},"locationmode":"country names","lon":[44.0075,47.4833],"mode":"lines+text","opacity":0.7,"text":"","type":"scattergeo"},{"hoverinfo":"none","lat":[42.9833,59.95],"line":{"color":"red","width":1},"locationmode":"country names","lon":[47.4833,30.3167],"mode":"lines+text","opacity":0.7,"text":"","type":"scattergeo"},{"hoverinfo":"none","lat":[59.95,53.3567],"line":{"color":"red","width":1},"locationmode":"country names","lon":[30.3167,83.7872],"mode":"lines+text","opacity":0.7,"text":"","type":"scattergeo"},{"hoverinfo":"none","lat":[53.3567,54.7333],"line":{"color":"red","width":1},"locationmode":"country names","lon":[83.7872,55.9667],"mode":"lines+text","opacity":0.7,"text":"","type":"scattergeo"},{"hoverinfo":"none","lat":[54.7333,53.1833],"line":{"color":"red","width":1},"locationmode":"country names","lon":[55.9667,50.1167],"mode":"lines+text","opacity":0.7,"text":"","type":"scattergeo"},{"hoverinfo":"none","lat":[53.1833,54.9667],"line":{"color":"red","width":1},"locationmode":"country names","lon":[50.1167,73.3833],"mode":"lines+text","opacity":0.7,"text":"","type":"scattergeo"},{"hoverinfo":"none","lat":[54.9667,55.0333],"line":{"color":"red","width":1},"locationmode":"country names","lon":[73.3833,82.9167],"mode":"lines+text","opacity":0.7,"text":"","type":"scattergeo"},{"hoverinfo":"none","lat":[55.0333,48.4833],"line":{"color":"red","width":1},"loca ...

# %% [markdown]
# ## Adapt SA for Visualization

# %%
class SARecorder(SA):
    def __init__(self, cities, annealing_rate=0.99):
        self.n = len(cities)

        self.cities = cities
        self.indices = [i for i, _ in enumerate(cities)]
        self.distances = get_cross_distances(cities)

        self.t = 0

        self.T_0 = 100_000
        self.T = self.T_0

        self.annealing_rate = annealing_rate

        self.x_t = self.sample_path()

        # Add this to super __init__
        self.frames = []
        self.make_frame()

        while self.T > 10:
            self.loop()
        else:
            print('Simulated Annealing Stopped')
            print(f'Total distance: {self.path_distance(self.x_t)} km')
            print(f'Took {self.t} iterations')

    def make_frame(self):
        self.frames += [self.x_t]

    def loop(self):
        x_next = self.sample_path(self.x_t)

        alpha = self.acceptance_ratio(x_next)
        u = self.generate_uniform()

        if alpha >= u:
            self.x_t = x_next

        self.t += 1

        if self.generate_uniform() < 0.2:
            self.T = self.T_0 * math.exp(-1 * self.annealing_rate * self.t)

        self.make_frame()

# %% [markdown]
# ## Select ~100 Frames

# %%
sa = SARecorder(cities, annealing_rate=0.0001)
# Out:
# Simulated Annealing Stopped
# Total distance: 18283.34990924752 km
# Took 92110 iterations

# %%
frames = sa.frames[::1000]

len(frames)
# Out:
# 93

# %% [markdown]
# ## "Animation"

# %%
def base_frame():
    return go.Scattergeo(
        locationmode='country names',
        lon=top_30['lng'],
        lat=top_30['lat'],
        text=top_30['city'],
        textfont=dict(
            color='rgb(0, 0, 0)'
        ),
        textposition='bottom right',
        hoverinfo='text',
        mode='markers',
        marker=dict(
            size=4,
            color='rgb(0, 0, 255)',
        )
    )


# https://plotly.com/python/lines-on-maps/

def draw_lines(x_t, cities):
    shortest_path = x_t
    shortest_path = [cities[idx] for idx in shortest_path]

    city_pairs = [
        (shortest_path[i - 1], shortest_path[i])
        for i in range(1, len(shortest_path))
    ]

    lats = np.empty(3 * len(city_pairs))
    lats[::3] = [city1.lat for city1, _ in city_pairs]
    lats[1::3] = [city2.lat for _, city2 in city_pairs]
    lats[2::3] = None

    lons = np.empty(3 * len(city_pairs))
    lons[::3] = [city1.lng for city1, _ in city_pairs]
    lons[1::3] = [city2.lng for _, city2 in city_pairs]
    lons[2::3] = None

    return go.Scattergeo(
        locationmode='country names',
        lat=lats,
        lon=lons,
        text='',
        hoverinfo='none',
        mode='markers+lines+text',
        line=dict(width=1, color='red'),
        opacity=0.7,
    )

# %%
fig = go.Figure(
    frames=[
        go.Frame(
            data=draw_lines(frames[i], sa.cities),
            name=str(i)
        )
        for i in range(len(frames))
    ]
)

fig.add_trace(
    base_frame()
)


# https://plotly.com/python/visualizing-mri-volume-slices/

def frame_args(duration):
    return {
        "frame": {"duration": duration},
        "mode": "immediate",
        "fromcurrent": True,
        "transition": {"duration": duration, "easing": "linear"}
    }


fig.update_layout(
    title_text='Animation of SA optimization',
    showlegend=False,
    geo=dict(
        scope='world',
        center=dict(
            lat=moscow['lat'][0],
            lon=moscow['lng'][0] + 22.0
        ),
        projection_rotation=dict(
            lat=moscow['lat'][0],
            lon=moscow['lng'][0],
            roll=-37
        ),
        projection_type='cylindrical stereographic',
        projection_scale=4.5,
        showland=True,
        showcountries=True,
        landcolor='rgb(243, 243, 243)',
        countrycolor='rgb(204, 204, 204)',
    ),
    # Interface: buttons + sliders
    # https://plotly.com/python/visualizing-mri-volume-slices/
    updatemenus=[{
        "buttons": [
            {
                "args": [None, frame_args(50)],
                "label": "&#9654;",  # play symbol
                "method": "animate",
            },
            {
                "args": [[None], frame_args(0)],
                "label": "&#9724;",  # pause symbol
                "method": "animate",
            },
        ],
        "direction": "left",
        "pad": {"r": 10, "t": 70},
        "type": "buttons",
        "x": 0.1,
        "y": 0,
    }],
    sliders=[{
        "pad": {"b": 10, "t": 60},
        "len": 0.9,
        "x": 0.1,
        "y": 0,
        "steps": [
            {
                "args": [[f.name], frame_args(0)],
                "label": str(k),
                "method": "animate",
            }
            for k, f in enumerate(fig.frames)
        ],
    }]
)

fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script src="https://cdn.plot.ly/plotly-2.8.3.min.js"></script>                <div id="1c2dcc88-cecf-4c11-b914-a5f2baad9693" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("1c2dcc88-cecf-4c11-b914-a5f2baad9693")) {                    Plotly.newPlot(                        "1c2dcc88-cecf-4c11-b914-a5f2baad9693",                        [{"hoverinfo":"text","lat":[55.7558,59.95,55.0333,56.8356,56.3269,55.7908,55.15,54.9667,53.1833,47.2333,54.7333,56.0167,58.0139,51.6717,48.7086,45.0333,51.5333,57.15,53.5167,56.85,53.3567,54.3167,52.2833,48.4833,57.6167,43.1167,42.9833,56.4886,51.7667,55.3333],"locationmode":"country names","lon":[37.6178,30.3167,82.9167,60.6128,44.0075,49.1144,61.4,73.3833,50.1167,39.7167,55.9667,92.8667,56.2489,39.2106,44.5147,38.9833,46.0,65.5333,49.4167,53.2167,83.7872,48.3667,104.3,135.0667,39.85,131.9,47.4833,84.9522,55.1,86.0667],"marker":{"color":"rgb(0, 0, 255)","size":4},"mode":"markers","text":["Moscow","Saint Petersburg","Novosibirsk","Yekaterinburg","Nizhniy Novgorod","Kazan","Chelyabinsk","Omsk","Samara","Rostov","Ufa","Krasnoyarsk","Perm","Voronezh","Volgograd","Krasnodar","Saratov","Tyumen","Tolyatti","Izhevsk","Barnaul","Ulyanovsk","Irkutsk","Khabarovsk","Yaroslavl","Vladivostok","Makhachkala","Tomsk","Orenburg","Kemerovo"],"textfont":{"color":"rgb(0, 0, 0)"},"textposition":"bottom right","type":"scattergeo"}],                        {"template":{"data":{"bar":[{"error_x":{"color":"#2a3f5f"},"error_y":{"color":"#2a3f5f"},"marker":{"line":{"color":"#E5ECF6","width":0.5},"pattern":{"fillmode":"overlay","size":10,"solidity":0.2}},"type":"bar"}],"barpolar":[{"marker":{"line":{"color":"#E5ECF6","width":0.5},"pattern":{"fillmode":"overlay","size":10,"solidity":0.2}},"type":"barpolar"}],"carpet":[{"aaxis":{"endlinecolor":"#2a3f5f","gridcolor":"white","linecolor":"white","minorgridcolor":"white","startlinecolor":"#2a3f5f"},"baxis":{"endlinecolor":"#2a3f5f","gridcolor":"white","linecolor":"white","minorgridcolor":"white","startlinecolor":"#2a3f5f"},"type":"carpet"}],"choropleth":[{"colorbar":{"outlinewidth":0,"ticks":""},"type":"choropleth"}],"contour":[{"colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]],"type":"contour"}],"contourcarpet":[{"colorbar":{"outlinewidth":0,"ticks":""},"type":"contourcarpet"}],"heatmap":[{"colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]],"type":"heatmap"}],"heatmapgl":[{"colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]],"type":"heatmapgl"}],"histogram":[{"marker":{"pattern":{"fillmode":"overlay","size":10,"solidity":0.2}},"type":"histogram"}],"histogram2d":[{"colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]],"type":"histogram2d"}],"histogram2dcontour":[ ...
